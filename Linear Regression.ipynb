# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_file=pd.read_csv("Archive\loan_data_train.csv")
test_file=pd.read_csv("Archive\loan_data_test (1).csv")

# %%
train_file
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     79542.0            25000                      25000        18.49%
# 1     75473.0            19750                      19750        17.27%
# 2     67265.0             2100                       2100        14.33%
# 3     80167.0            28000                      28000        16.29%
# 4     17240.0            24250                   17431.82        12.23%
# ...       ...              ...                        ...           ...
# 2195  74047.0            30000                      30000        23.28%
# 2196  63768.0             4200                       4200        14.33%
# 2197  94545.0            19800                      19775        15.31%
# 2198  53635.0            18000                      18000        20.99%
# 2199  67953.0             7550                       7550        10.16%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
test_file
# Out:
#         ID  Amount.Requested Amount.Funded.By.Investors Loan.Length  \
# 0    20093              5000                       5000   60 months
# 1    62445             18000                      18000   60 months
# 2    65248              7200                       7200   60 months
# 3    81822              7200                       7200   36 months
# 4    57923             22000                      22000   60 months
# ..     ...               ...                        ...         ...
# 295  24675             12000                      11975   60 months
# 296  69456              5000                       5000   36 months
# 297  97954              4375                       4375   36 months
# 298  36931             13600                      13600   60 months
# 299  34744              6000                       6000   36 months
#
#            Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0                moving               12.59%    NY           RENT
# ...

# %%
train_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              2199 non-null   float64
#  1   Amount.Requested                2199 non-null   object
#  2   Amount.Funded.By.Investors      2199 non-null   object
#  3   Interest.Rate                   2200 non-null   object
#  4   Loan.Length                     2199 non-null   object
#  5   Loan.Purpose                    2199 non-null   object
#  6   Debt.To.Income.Ratio            2199 non-null   object
#  7   State                           2199 non-null   object
#  8   Home.Ownership                  2199 non-null   object
#  9   Monthly.Income                  2197 non-null   float64
#  10  FICO.Range                      2200 non-null   object
#  11  Open.CREDIT.Lines               2196 non-null   object
# ...

# %%
test_file["Interest.Rate"]=np.nan

# %%
test_file["data"]="Test"
train_file["data"]="Train"

# %%
df=pd.concat([test_file,train_file],ignore_index=True)

# %%
df
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Loan.Length  \
# 0     20093.0             5000                       5000   60 months
# 1     62445.0            18000                      18000   60 months
# 2     65248.0             7200                       7200   60 months
# 3     81822.0             7200                       7200   36 months
# 4     57923.0            22000                      22000   60 months
# ...       ...              ...                        ...         ...
# 2495  74047.0            30000                      30000   60 months
# 2496  63768.0             4200                       4200   60 months
# 2497  94545.0            19800                      19775   60 months
# 2498  53635.0            18000                      18000   60 months
# 2499  67953.0             7550                       7550   36 months
#
#             Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              2499 non-null   float64
#  1   Amount.Requested                2499 non-null   object
#  2   Amount.Funded.By.Investors      2499 non-null   object
#  3   Loan.Length                     2499 non-null   object
#  4   Loan.Purpose                    2499 non-null   object
#  5   Debt.To.Income.Ratio            2499 non-null   object
#  6   State                           2499 non-null   object
#  7   Home.Ownership                  2499 non-null   object
#  8   Monthly.Income                  2497 non-null   float64
#  9   FICO.Range                      2500 non-null   object
#  10  Open.CREDIT.Lines               2496 non-null   object
#  11  Revolving.CREDIT.Balance        2497 non-null   object
# ...

# %%
df.drop(columns="ID",inplace=True)

# %% [markdown]
# ## Amount Requested

# %%
df["Amount.Requested"].fillna(".",inplace=True)

# %%
df[df["Amount.Requested"]=="."]
# Out:
#      Amount.Requested Amount.Funded.By.Investors Loan.Length  \
# 671                 .                       1850   36 months
# 1657                .                      12000   36 months
# 1976                .                      10000   36 months
# 2091                .                      15875   36 months
# 2291                .                       7000   36 months
#
#             Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 671     home_improvement               20.56%    MD       MORTGAGE
# 1657  debt_consolidation               27.48%    VA       MORTGAGE
# 1976              moving                2.18%    CA           RENT
# 2091      small_business               17.44%    MD       MORTGAGE
# 2291         credit_card                7.10%    CA           RENT
#
#       Monthly.Income FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# 671          3448.33    660-664                10                    18749
# ...

# %%
for i in range(len(df["Amount.Requested"])):
    try:
        df["Amount.Requested"][i]=float(df["Amount.Requested"][i])
    except:
        df["Amount.Requested"][i]= float(df["Amount.Funded.By.Investors"][i])
# Out:
# C:\Users\aarya\AppData\Local\Temp/ipykernel_17444/1898582054.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Amount.Requested"][i]=float(df["Amount.Requested"][i])
# C:\Users\aarya\AppData\Local\Temp/ipykernel_17444/1898582054.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Amount.Requested"][i]= float(df["Amount.Funded.By.Investors"][i])

# %%
df["Amount.Requested"]=df["Amount.Requested"].astype(float)

# %% [markdown]
# ## Amount.Funded.By.Investors

# %%
df["Amount.Funded.By.Investors"].fillna(".", inplace=True)
for i in range(len(df["Amount.Funded.By.Investors"])):
    try:
        df["Amount.Funded.By.Investors"][i] = float(df["Amount.Funded.By.Investors"][i])
    except:
        df["Amount.Funded.By.Investors"][i] = float(df["Amount.Requested"][i])
# Out:
# C:\Users\aarya\AppData\Local\Temp/ipykernel_17444/4029641319.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Amount.Funded.By.Investors"][i] = float(df["Amount.Funded.By.Investors"][i])
# C:\Users\aarya\AppData\Local\Temp/ipykernel_17444/4029641319.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Amount.Funded.By.Investors"][i] = float(df["Amount.Requested"][i])

# %%
df["Amount.Funded.By.Investors"] = df["Amount.Funded.By.Investors"].astype(
    float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Amount.Requested                2500 non-null   float64
#  1   Amount.Funded.By.Investors      2500 non-null   float64
#  2   Loan.Length                     2499 non-null   object
#  3   Loan.Purpose                    2499 non-null   object
#  4   Debt.To.Income.Ratio            2499 non-null   object
#  5   State                           2499 non-null   object
#  6   Home.Ownership                  2499 non-null   object
#  7   Monthly.Income                  2497 non-null   float64
#  8   FICO.Range                      2500 non-null   object
#  9   Open.CREDIT.Lines               2496 non-null   object
#  10  Revolving.CREDIT.Balance        2497 non-null   object
#  11  Inquiries.in.the.Last.6.Months  2497 non-null   float64
# ...

# %%
df.drop(columns="Amount.Funded.By.Investors", inplace=True)

# %%
df
# Out:
#       Amount.Requested Loan.Length        Loan.Purpose Debt.To.Income.Ratio  \
# 0               5000.0   60 months              moving               12.59%
# 1              18000.0   60 months  debt_consolidation                4.93%
# 2               7200.0   60 months  debt_consolidation               25.16%
# 3               7200.0   36 months  debt_consolidation               17.27%
# 4              22000.0   60 months  debt_consolidation               18.28%
# ...                ...         ...                 ...                  ...
# 2495           30000.0   60 months               other               12.10%
# 2496            4200.0   60 months                 car               14.16%
# 2497           19800.0   60 months  debt_consolidation               15.03%
# 2498           18000.0   60 months         credit_card               11.63%
# 2499            7550.0   36 months  debt_consolidation                3.83%
#
# ...

# %%
# df[df["Amount.Requested"] == "."]
# df[df["Loan.Length"] == "."] 1518
# df[df["Loan.Purpose"] == "."]
# df[df["Debt.To.Income.Ratio"] == "."]
# df[df["State"] == "."] 2218
# df[df["Home.Ownership"] == "."]
# df[df["Monthly.Income"] == "."]
# df[df["FICO.Range"] == "."]
# df[df["Open.CREDIT.Lines"] == "."] 5 135 398 1683 2207
# df[df["Revolving.CREDIT.Balance"] == "."] 1674 2040
# df[df["Inquiries.in.the.Last.6.Months"] == "."]
# df[df["Employment.Length"] == "."] # 247 859
# df[df["Interest.Rate"] == "."]

# %%
# sns.barplot(x=df["State"], y=df["Interest.Rate"])
df["Interest.Rate"] = df["Interest.Rate"].str.replace("%", "").astype(float)

# %%
df["Interest.Rate"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 2495    23.28
# 2496    14.33
# 2497    15.31
# 2498    20.99
# 2499    10.16
# Name: Interest.Rate, Length: 2500, dtype: float64

# %%
ax, fig = plt.rcParams["figure.figsize"] = (15, 5)
sns.barplot(y=df["Interest.Rate"], x=df["State"])
plt.xticks(rotation="vertical")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dict1=dict(df["State"].value_counts())

# %%
list2=[]
for i in dict1:
    if dict1[i]>20:
        list2.append(i)
list2
# Out:
# ['CA',
#  'NY',
#  'TX',
#  'FL',
#  'IL',
#  'GA',
#  'PA',
#  'NJ',
#  'VA',
#  'MA',
#  'OH',
#  'MD',
#  'NC',
#  'CO',
#  'WA',
#  'CT',
#  'AZ',
#  'MI',
#  'AL',
#  'MN',
#  'MO',
#  'NV',
#  'OR',
#  'SC',
#  'WI',
#  'KY',
#  'LA',
#  'OK',
#  'KS']

# %%
df["New_States"]="nan"

# %%
for i in range(len(df["State"])):
    if df["State"][i] in list2:
        df["New_States"][i]=df["State"][i]
    else:
        df["New_States"][i]="Others"
# Out:
# C:\Users\aarya\AppData\Local\Temp/ipykernel_17444/1748896501.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["New_States"][i]=df["State"][i]
# C:\Users\aarya\AppData\Local\Temp/ipykernel_17444/1748896501.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["New_States"][i]="Others"

# %%
ax, fig = plt.rcParams["figure.figsize"] = (15, 5)
sns.barplot(y=df["Interest.Rate"], x=df["New_States"])
plt.xticks(rotation="vertical")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
k = pd.get_dummies(df['New_States'],prefix ='New_States')
df=pd.concat([df,k],axis=1)

# %%
df.drop(columns="State",inplace=True)

# %%
df.drop(columns="New_States", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 43 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Amount.Requested                2500 non-null   float64
#  1   Loan.Length                     2499 non-null   object
#  2   Loan.Purpose                    2499 non-null   object
#  3   Debt.To.Income.Ratio            2499 non-null   object
#  4   Home.Ownership                  2499 non-null   object
#  5   Monthly.Income                  2497 non-null   float64
#  6   FICO.Range                      2500 non-null   object
#  7   Open.CREDIT.Lines               2496 non-null   object
#  8   Revolving.CREDIT.Balance        2497 non-null   object
#  9   Inquiries.in.the.Last.6.Months  2497 non-null   float64
#  10  Employment.Length               2422 non-null   object
#  11  Interest.Rate                   2200 non-null   float64
# ...

# %% [markdown]
# ## Loan Length

# %%
df["Loan.Length"]=df["Loan.Length"].str.replace("months","")
df["Loan.Length"]=df["Loan.Length"].str.replace(".","36")
# Out:
# C:\Users\aarya\AppData\Local\Temp/ipykernel_17444/2666481201.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Loan.Length"]=df["Loan.Length"].str.replace(".","36")

# %%
df[df["Loan.Length"].isnull()]
# Out:
#       Amount.Requested Loan.Length        Loan.Purpose Debt.To.Income.Ratio  \
# 1247            4800.0         NaN  debt_consolidation               19.07%
#
#      Home.Ownership  Monthly.Income FICO.Range Open.CREDIT.Lines  \
# 1247           RENT             NaN    720-724                12
#
#      Revolving.CREDIT.Balance  Inquiries.in.the.Last.6.Months  ...  \
# 1247                     6813                             3.0  ...
#
#      New_States_OH  New_States_OK New_States_OR  New_States_Others  \
# 1247             1              0             0                  0
#
#       New_States_PA  New_States_SC  New_States_TX  New_States_VA  \
# 1247              0              0              0              0
#
#       New_States_WA  New_States_WI
# 1247              0              0
#
# [1 rows x 43 columns]

# %%
df["Loan.Length"].fillna("36",inplace=True)

# %%
df["Loan.Length"]=df["Loan.Length"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 43 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Amount.Requested                2500 non-null   float64
#  1   Loan.Length                     2500 non-null   int32
#  2   Loan.Purpose                    2499 non-null   object
#  3   Debt.To.Income.Ratio            2499 non-null   object
#  4   Home.Ownership                  2499 non-null   object
#  5   Monthly.Income                  2497 non-null   float64
#  6   FICO.Range                      2500 non-null   object
#  7   Open.CREDIT.Lines               2496 non-null   object
#  8   Revolving.CREDIT.Balance        2497 non-null   object
#  9   Inquiries.in.the.Last.6.Months  2497 non-null   float64
#  10  Employment.Length               2422 non-null   object
#  11  Interest.Rate                   2200 non-null   float64
# ...

# %% [markdown]
# ## Loan Purpose

# %%
df["Loan.Purpose"].value_counts()
# Out:
# debt_consolidation    1307
# credit_card            444
# other                  200
# home_improvement       152
# major_purchase         101
# small_business          87
# car                     50
# wedding                 39
# medical                 30
# moving                  29
# vacation                21
# house                   20
# educational             15
# renewable_energy         4
# Name: Loan.Purpose, dtype: int64

# %%
ax, fig = plt.rcParams["figure.figsize"] = (15, 5)
sns.barplot(y=df["Interest.Rate"], x=df["Loan.Purpose"])
plt.xticks(rotation="vertical")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df["Loan.Purpose"].value_counts()
# Out:
# debt_consolidation    1307
# credit_card            444
# other                  200
# home_improvement       152
# major_purchase         101
# small_business          87
# car                     50
# wedding                 39
# medical                 30
# moving                  29
# vacation                21
# house                   20
# educational             15
# renewable_energy         4
# Name: Loan.Purpose, dtype: int64

# %%
k = pd.get_dummies(df['Loan.Purpose'],prefix ='Loan_purpose')

# %%
df.drop(['Loan.Purpose'],axis=1, inplace=True)

df = pd.concat([df,k],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 56 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Amount.Requested                 2500 non-null   float64
#  1   Loan.Length                      2500 non-null   int32
#  2   Debt.To.Income.Ratio             2499 non-null   object
#  3   Home.Ownership                   2499 non-null   object
#  4   Monthly.Income                   2497 non-null   float64
#  5   FICO.Range                       2500 non-null   object
#  6   Open.CREDIT.Lines                2496 non-null   object
#  7   Revolving.CREDIT.Balance         2497 non-null   object
#  8   Inquiries.in.the.Last.6.Months   2497 non-null   float64
#  9   Employment.Length                2422 non-null   object
#  10  Interest.Rate                    2200 non-null   float64
#  11  data                             2500 non-null   object
# ...

# %% [markdown]
# ## Debt to income ratio

# %%
df["Debt.To.Income.Ratio"]=df["Debt.To.Income.Ratio"].str.replace("%","")

# %%
df["Debt.To.Income.Ratio"].astype(float)
# Out:
# 0       12.59
# 1        4.93
# 2       25.16
# 3       17.27
# 4       18.28
#         ...
# 2495    12.10
# 2496    14.16
# 2497    15.03
# 2498    11.63
# 2499     3.83
# Name: Debt.To.Income.Ratio, Length: 2500, dtype: float64

# %%
df[df["Debt.To.Income.Ratio"].isna()]
# Out:
#       Amount.Requested  Loan.Length Debt.To.Income.Ratio Home.Ownership  \
# 2246           12000.0           36                  NaN       MORTGAGE
#
#       Monthly.Income FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# 2246         7083.33    665-669                16                    16993
#
#       Inquiries.in.the.Last.6.Months Employment.Length  ...  \
# 2246                             2.0           7 years  ...
#
#       Loan_purpose_home_improvement Loan_purpose_house  \
# 2246                              0                  0
#
#       Loan_purpose_major_purchase  Loan_purpose_medical  Loan_purpose_moving  \
# 2246                            0                     0                    0
#
#       Loan_purpose_other  Loan_purpose_renewable_energy  \
# 2246                   0                              0
#
#       Loan_purpose_small_business  Loan_purpose_vacation  Loan_purpose_wedding
# ...

# %%
df["Debt.To.Income.Ratio"].fillna(np.mean(df["Debt.To.Income.Ratio"].astype(float)), inplace=True)

# %%
df[df["Debt.To.Income.Ratio"].isna()]
# Out:
# Empty DataFrame
# ...

# %%
df["Debt.To.Income.Ratio"] = df["Debt.To.Income.Ratio"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 56 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Amount.Requested                 2500 non-null   float64
#  1   Loan.Length                      2500 non-null   int32
#  2   Debt.To.Income.Ratio             2500 non-null   float64
#  3   Home.Ownership                   2499 non-null   object
#  4   Monthly.Income                   2497 non-null   float64
#  5   FICO.Range                       2500 non-null   object
#  6   Open.CREDIT.Lines                2496 non-null   object
#  7   Revolving.CREDIT.Balance         2497 non-null   object
#  8   Inquiries.in.the.Last.6.Months   2497 non-null   float64
#  9   Employment.Length                2422 non-null   object
#  10  Interest.Rate                    2200 non-null   float64
#  11  data                             2500 non-null   object
# ...

# %%
df.corr()
# Out:
#                                  Amount.Requested  Loan.Length  \
# Amount.Requested                         1.000000     0.412513
# Loan.Length                              0.412513     1.000000
# Debt.To.Income.Ratio                     0.082229     0.025611
# Monthly.Income                           0.389677     0.073884
# Inquiries.in.the.Last.6.Months          -0.029749     0.023689
# Interest.Rate                            0.330267     0.424456
# New_States_AL                            0.005223     0.013201
# New_States_AZ                           -0.001589    -0.007793
# New_States_CA                           -0.011687    -0.035550
# New_States_CO                           -0.002944    -0.021126
# New_States_CT                           -0.004336    -0.006630
# New_States_FL                           -0.014913    -0.023280
# New_States_GA                            0.026020     0.013706
# New_States_IL                            0.019401     0.014048
# ...

# %% [markdown]
# ## Home.Ownership

# %%
df["Home.Ownership"].value_counts()
# Out:
# MORTGAGE    1147
# RENT        1146
# OWN          200
# OTHER          5
# NONE           1
# Name: Home.Ownership, dtype: int64

# %%
ax, fig = plt.rcParams["figure.figsize"] = (15, 5)
sns.barplot(y=df["Interest.Rate"], x=df["Home.Ownership"])
plt.xticks(rotation="vertical")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Home.Ownership'].value_counts()

df.loc[df['Home.Ownership'].isin(['OTHER','NONE']),'Home.Ownership'] = 'RENT'

k = pd.get_dummies(df['Home.Ownership'],prefix = 'HO')

df.drop(['Home.Ownership'],axis=1,inplace=True) #### del df['Home.Ownership']

df = pd.concat([df,k],axis=1)

# %%
# df.drop(columns="Home.Ownership", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 58 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Amount.Requested                 2500 non-null   float64
#  1   Loan.Length                      2500 non-null   int32
#  2   Debt.To.Income.Ratio             2500 non-null   float64
#  3   Monthly.Income                   2497 non-null   float64
#  4   FICO.Range                       2500 non-null   object
#  5   Open.CREDIT.Lines                2496 non-null   object
#  6   Revolving.CREDIT.Balance         2497 non-null   object
#  7   Inquiries.in.the.Last.6.Months   2497 non-null   float64
#  8   Employment.Length                2422 non-null   object
#  9   Interest.Rate                    2200 non-null   float64
#  10  data                             2500 non-null   object
#  11  New_States_AL                    2500 non-null   uint8
# ...

# %% [markdown]
# ## FICO Range

# %%
df
# Out:
#       Amount.Requested  Loan.Length  Debt.To.Income.Ratio  Monthly.Income  \
# 0               5000.0           60                 12.59         4416.67
# 1              18000.0           60                  4.93         5258.50
# 2               7200.0           60                 25.16         3750.00
# 3               7200.0           36                 17.27         3416.67
# 4              22000.0           60                 18.28         6083.33
# ...                ...          ...                   ...             ...
# 2495           30000.0           60                 12.10         7083.33
# 2496            4200.0           60                 14.16         3850.00
# 2497           19800.0           60                 15.03         6666.67
# 2498           18000.0           60                 11.63         9051.83
# 2499            7550.0           36                  3.83         8333.33
#
#      FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# ...

# %%
df["FICO.Range"].unique()
# Out:
# array(['690-694', '710-714', '750-754', '790-794', '720-724', '715-719',
#        '665-669', '675-679', '705-709', '685-689', '700-704', '660-664',
#        '680-684', '725-729', '695-699', '655-659', '775-779', '735-739',
#        '670-674', '745-749', '730-734', '760-764', '805-809', '740-744',
#        '755-759', '765-769', '785-789', '810-814', '780-784', '795-799',
#        '770-774', '800-804', '640-644', '815-819', '820-824', '645-649',
#        '830-834', '650-654'], dtype=object)

# %%
df["FICO.Range"]=df["FICO.Range"].apply(lambda x: x.split("-"))

# %%
df["FICO.Range"]
# Out:
# 0       [690, 694]
# 1       [710, 714]
# 2       [750, 754]
# 3       [790, 794]
# 4       [720, 724]
#            ...
# 2495    [675, 679]
# 2496    [700, 704]
# 2497    [675, 679]
# 2498    [670, 674]
# 2499    [710, 714]
# Name: FICO.Range, Length: 2500, dtype: object

# %%
df["FICO.Range"]=df["FICO.Range"].apply(lambda x: (int(x[0])+int(x[1]))/2)

# %%
df["FICO.Range"]
# Out:
# 0       692.0
# 1       712.0
# 2       752.0
# 3       792.0
# 4       722.0
#         ...
# 2495    677.0
# 2496    702.0
# 2497    677.0
# 2498    672.0
# 2499    712.0
# Name: FICO.Range, Length: 2500, dtype: float64

# %%
df.corr()
# Out:
#                                  Amount.Requested  Loan.Length  \
# Amount.Requested                         1.000000     0.412513
# Loan.Length                              0.412513     1.000000
# Debt.To.Income.Ratio                     0.082229     0.025611
# Monthly.Income                           0.389677     0.073884
# FICO.Range                               0.082500     0.012239
# Inquiries.in.the.Last.6.Months          -0.029749     0.023689
# Interest.Rate                            0.330267     0.424456
# New_States_AL                            0.005223     0.013201
# New_States_AZ                           -0.001589    -0.007793
# New_States_CA                           -0.011687    -0.035550
# New_States_CO                           -0.002944    -0.021126
# New_States_CT                           -0.004336    -0.006630
# New_States_FL                           -0.014913    -0.023280
# New_States_GA                            0.026020     0.013706
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 58 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Amount.Requested                 2500 non-null   float64
#  1   Loan.Length                      2500 non-null   int32
#  2   Debt.To.Income.Ratio             2500 non-null   float64
#  3   Monthly.Income                   2497 non-null   float64
#  4   FICO.Range                       2500 non-null   float64
#  5   Open.CREDIT.Lines                2496 non-null   object
#  6   Revolving.CREDIT.Balance         2497 non-null   object
#  7   Inquiries.in.the.Last.6.Months   2497 non-null   float64
#  8   Employment.Length                2422 non-null   object
#  9   Interest.Rate                    2200 non-null   float64
#  10  data                             2500 non-null   object
#  11  New_States_AL                    2500 non-null   uint8
# ...

# %%
df
# Out:
#       Amount.Requested  Loan.Length  Debt.To.Income.Ratio  Monthly.Income  \
# 0               5000.0           60                 12.59         4416.67
# 1              18000.0           60                  4.93         5258.50
# 2               7200.0           60                 25.16         3750.00
# 3               7200.0           36                 17.27         3416.67
# 4              22000.0           60                 18.28         6083.33
# ...                ...          ...                   ...             ...
# 2495           30000.0           60                 12.10         7083.33
# 2496            4200.0           60                 14.16         3850.00
# 2497           19800.0           60                 15.03         6666.67
# 2498           18000.0           60                 11.63         9051.83
# 2499            7550.0           36                  3.83         8333.33
#
#       FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# ...

# %% [markdown]
# ## Open Credit Line

# %%
df["Open.CREDIT.Lines"].value_counts()
# Out:
# 8     259
# 9     236
# 6     232
# 7     216
# 11    187
# 10    185
# 13    157
# 12    153
# 5     153
# 14    138
# 4     105
# 15     96
# 16     66
# 3      59
# 17     58
# 18     51
# 19     30
# 21     26
# 2      24
# 20     23
# 23     11
# 22      8
# 24      7
# .       5
# 25      4
# 26      3
# 36      1
# 31      1
# 34      1
# 38      1
# Name: Open.CREDIT.Lines, dtype: int64

# %%
df["Open.CREDIT.Lines"] = df["Open.CREDIT.Lines"].str.replace(".", "0")
# Out:
# C:\Users\aarya\AppData\Local\Temp/ipykernel_17444/1025654487.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Open.CREDIT.Lines"] = df["Open.CREDIT.Lines"].str.replace(".", "0")

# %%
df["Open.CREDIT.Lines"].fillna(
    np.mean(df["Open.CREDIT.Lines"].astype(float)), inplace=True)
df["Open.CREDIT.Lines"] = df["Open.CREDIT.Lines"].astype(int)

# %%
df.corr()
# Out:
#                                  Amount.Requested  Loan.Length  \
# Amount.Requested                         1.000000     0.412513
# Loan.Length                              0.412513     1.000000
# Debt.To.Income.Ratio                     0.082229     0.025611
# Monthly.Income                           0.389677     0.073884
# FICO.Range                               0.082500     0.012239
# Open.CREDIT.Lines                        0.194868     0.042279
# Inquiries.in.the.Last.6.Months          -0.029749     0.023689
# Interest.Rate                            0.330267     0.424456
# New_States_AL                            0.005223     0.013201
# New_States_AZ                           -0.001589    -0.007793
# New_States_CA                           -0.011687    -0.035550
# New_States_CO                           -0.002944    -0.021126
# New_States_CT                           -0.004336    -0.006630
# New_States_FL                           -0.014913    -0.023280
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 58 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Amount.Requested                 2500 non-null   float64
#  1   Loan.Length                      2500 non-null   int32
#  2   Debt.To.Income.Ratio             2500 non-null   float64
#  3   Monthly.Income                   2497 non-null   float64
#  4   FICO.Range                       2500 non-null   float64
#  5   Open.CREDIT.Lines                2500 non-null   int32
#  6   Revolving.CREDIT.Balance         2497 non-null   object
#  7   Inquiries.in.the.Last.6.Months   2497 non-null   float64
#  8   Employment.Length                2422 non-null   object
#  9   Interest.Rate                    2200 non-null   float64
#  10  data                             2500 non-null   object
#  11  New_States_AL                    2500 non-null   uint8
# ...

# %% [markdown]
# ## Employment Length

# %%
df["Employment.Length"].value_counts()
# Out:
# 10+ years    653
# < 1 year     249
# 2 years      243
# 3 years      235
# 5 years      202
# 4 years      191
# 1 year       177
# 6 years      163
# 7 years      127
# 8 years      108
# 9 years       72
# .              2
# Name: Employment.Length, dtype: int64

# %%
df["Employment.Length"]=df["Employment.Length"].str.replace("years","")
df["Employment.Length"]=df["Employment.Length"].str.replace("year","")
df["Employment.Length"]=df["Employment.Length"].str.replace(".","10")
df["Employment.Length"]=df["Employment.Length"].str.replace("< 1","0.5")
# Out:
# C:\Users\aarya\AppData\Local\Temp/ipykernel_17444/3792562761.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Employment.Length"]=df["Employment.Length"].str.replace(".","10")

# %%
df["Employment.Length"]=df["Employment.Length"].str.replace("+","")
# Out:
# C:\Users\aarya\AppData\Local\Temp/ipykernel_17444/3415817998.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Employment.Length"]=df["Employment.Length"].str.replace("+","")

# %%
df["Employment.Length"].value_counts()
# Out:
# 10      653
# 0.5     249
# 2       243
# 3       235
# 5       202
# 4       191
# 1       177
# 6       163
# 7       127
# 8       108
# 9        72
# 10        2
# Name: Employment.Length, dtype: int64

# %%
df["Employment.Length"] = df["Employment.Length"].astype(float)

# %%
sns.barplot(y=df["Interest.Rate"],x=df["Employment.Length"])
# Out:
# <AxesSubplot:xlabel='Employment.Length', ylabel='Interest.Rate'>

# %% [markdown]
# ## Revolving Credit Balance

# %%
qqqq = df[df["Revolving.CREDIT.Balance"] != "."]
qqqq = np.mean(qqqq["Revolving.CREDIT.Balance"].astype(float))
df["Revolving.CREDIT.Balance"] = df["Revolving.CREDIT.Balance"].str.replace(".", str(qqqq))
# Out:
# C:\Users\aarya\AppData\Local\Temp/ipykernel_17444/3875690190.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Revolving.CREDIT.Balance"] = df["Revolving.CREDIT.Balance"].str.replace(".", str(qqqq))

# %%
df["Revolving.CREDIT.Balance"] = df["Revolving.CREDIT.Balance"].astype(float)

# %%
df["Monthly.Income"].fillna(np.mean(df["Monthly.Income"]), inplace=True)
df["Revolving.CREDIT.Balance"].fillna(np.mean(df["Revolving.CREDIT.Balance"]), inplace=True)
df["Inquiries.in.the.Last.6.Months"].fillna(np.mean(df["Inquiries.in.the.Last.6.Months"]), inplace=True)
df["Employment.Length"].fillna(np.mean(df["Employment.Length"]), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 58 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Amount.Requested                 2500 non-null   float64
#  1   Loan.Length                      2500 non-null   int32
#  2   Debt.To.Income.Ratio             2500 non-null   float64
#  3   Monthly.Income                   2500 non-null   float64
#  4   FICO.Range                       2500 non-null   float64
#  5   Open.CREDIT.Lines                2500 non-null   int32
#  6   Revolving.CREDIT.Balance         2500 non-null   float64
#  7   Inquiries.in.the.Last.6.Months   2500 non-null   float64
#  8   Employment.Length                2500 non-null   float64
#  9   Interest.Rate                    2200 non-null   float64
#  10  data                             2500 non-null   object
#  11  New_States_AL                    2500 non-null   uint8
# ...

# %% [markdown]
# ## Outliers Removal

# %%
genuine_numeric_cols = ['Amount.Requested','Loan_Length','Interest.Rate', 'Debt.To.Income.Ratio',
                        'Monthly.Income', 'Open.CREDIT.Lines', 'Revolving.CREDIT.Balance',
                        'Inquiries.in.the.Last.6.Months', 'FICO.Range','Employment.Length']

# numeric_cols = df.loc[df['data']=='Train',genuine_numeric_cols] ### selects numeric columns

# column_names = list(numeric_cols.columns)

# col_index = 0

# plot_rows = 3
# plot_cols = 3

# fig, ax = plt.subplots(nrows = plot_rows,ncols=plot_cols,figsize = (20,20))

# for row_count in range(plot_rows):
#     for col_count in range(plot_cols):
#         ax[row_count][col_count].scatter(y = numeric_cols[column_names[col_index]],x=numeric_cols.index)
#         ax[row_count][col_count].set_ylabel(column_names[col_index])
#         col_index = col_index + 1

sns.scatterplot(df["Employment.Length"], df["Interest.Rate"])
# Out:
# C:\Users\aarya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Employment.Length', ylabel='Interest.Rate'>

# %%
df[df["Monthly.Income"] >= 20000] = 20000
df[df["Open.CREDIT.Lines"] >= 25] = 25
df[df["Revolving.CREDIT.Balance"] >= 100000] = 100000
df[df["Inquiries.in.the.Last.6.Months"] >= 6] = 6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 58 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Amount.Requested                 2500 non-null   float64
#  1   Loan.Length                      2500 non-null   int32
#  2   Debt.To.Income.Ratio             2500 non-null   float64
#  3   Monthly.Income                   2500 non-null   float64
#  4   FICO.Range                       2500 non-null   float64
#  5   Open.CREDIT.Lines                2500 non-null   int32
#  6   Revolving.CREDIT.Balance         2500 non-null   float64
#  7   Inquiries.in.the.Last.6.Months   2500 non-null   float64
#  8   Employment.Length                2500 non-null   float64
#  9   Interest.Rate                    2208 non-null   float64
#  10  data                             2500 non-null   object
#  11  New_States_AL                    2500 non-null   uint8
# ...

# %%
# genuine_numeric_cols = ['Amount.Requested', 'Interest.Rate', 'Debt.To.Income.Ratio',
#                         'Monthly.Income', 'Open.CREDIT.Lines', 'Revolving.CREDIT.Balance',
#                         'Inquiries.in.the.Last.6.Months', 'FICO.Range']

# numeric_cols = df.loc[df['data']=='Train',genuine_numeric_cols] ### selects numeric columns

# column_names = list(numeric_cols.columns)

# col_index = 0

# plot_rows = 3
# plot_cols = 3

# fig, ax = plt.subplots(nrows = plot_rows,ncols=plot_cols,figsize = (20,20))

# for row_count in range(plot_rows):
#     for col_count in range(plot_cols):
#         ax[row_count][col_count].scatter(y = numeric_cols[column_names[col_index]],x=numeric_cols.index)
#         ax[row_count][col_count].set_ylabel(column_names[col_index])
#         col_index = col_index + 1

# %% [markdown]
# ## Distribution Plot

# %%
# genuine_numeric_cols = ['Amount.Requested', 'Interest.Rate', 'Debt.To.Income.Ratio',
#                         'Monthly.Income', 'Open.CREDIT.Lines', 'Revolving.CREDIT.Balance',
#                         'Inquiries.in.the.Last.6.Months', 'FICO.Range']
# fig, ax = plt.subplots(figsize = (20,20))
# for i, column in enumerate(genuine_numeric_cols, 1):
#     plt.subplot(3,3,i)
#     sns.distplot(np.log(df[column]))

# %% [markdown]
# ## Model Selection

# %%
X = df[df["data"] == "Train"]
Y = df[df["data"] == "Test"]

# %%
from sklearn.model_selection import train_test_split

# %%
ld_new_train, ld_val = train_test_split(X, test_size=0.2, random_state=100)

# %%
train_features = ld_new_train.drop(['Interest.Rate','data'],axis=1) ## this contains features for train

train_targets = ld_new_train['Interest.Rate'] ### this contains the actual value for train set

val_features = ld_val.drop(['Interest.Rate','data'],axis=1) ### this contains features for validation set

val_targets = ld_val['Interest.Rate']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
cols=["Amount.Requested","Loan.Length","Debt.To.Income.Ratio","Monthly.Income","FICO.Range","Open.CREDIT.Lines","Revolving.CREDIT.Balance","Inquiries.in.the.Last.6.Months","Employment.Length"]

# %%
X_test=Y

# %%
for i in cols:
    
    # fit on training data column
    scale = StandardScaler().fit(train_features[[i]])
    
    # transform the training data column
    train_features[i] = scale.transform (train_features[[i]])
    val_features[i] = scale.transform (val_features[[i]])
    
    # transform the testing data column
    X_test[i] = scale.transform(X_test[[i]])
# Out:
# C:\Users\aarya\AppData\Local\Temp/ipykernel_17444/3089000756.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[i] = scale.transform(X_test[[i]])
# C:\Users\aarya\AppData\Local\Temp/ipykernel_17444/3089000756.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[i] = scale.transform(X_test[[i]])
# C:\Users\aarya\AppData\Local\Temp/ipykernel_17444/3089000756.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
train_features
# Out:
#       Amount.Requested  Loan.Length  Debt.To.Income.Ratio  Monthly.Income  \
# 1791         -0.959033    -0.532314              0.848754       -0.483777
# 571           0.713565     1.878590             -1.765862       -0.413477
# 441          -0.830371    -0.532314             -1.161672        1.736300
# 1516         -1.139158     1.878590              0.901869       -0.827150
# 1925         -0.904351    -0.532314              0.761113        0.285847
# ...                ...          ...                   ...             ...
# 658          -1.152025    -0.532314             -0.132557        1.292284
# 2282         -0.959033    -0.532314              0.034757       -0.039762
# 383           0.713565    -0.532314             -0.675664       -0.706378
# 2207         -1.216355    -0.532314              0.285728       -0.735388
# 1884         -0.058403    -0.532314             -0.739403       -0.868593
#
#       FICO.Range  Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# ...

# %%
val_features
# Out:
#       Amount.Requested  Loan.Length  Debt.To.Income.Ratio  Monthly.Income  \
# 451          -0.573048    -0.532314             -1.449824       -0.720587
# 1587         -0.341458    -0.532314             -0.131229        0.404254
# 2292          1.485533     1.878590             -0.858913       -0.187768
# 1134         -0.830371    -0.532314             -1.715402        0.700263
# 1183          0.430510     1.878590              0.559274        0.660628
# ...                ...          ...                   ...             ...
# 907          -1.087694     1.878590             -0.228165       -0.365374
# 597           0.970888    -0.532314              0.531388        0.256247
# 2264         -1.100560    -0.532314             -1.046145       -1.046199
# 1469         -0.862536    -0.532314              1.170103       -1.368849
# 2082         -0.959033    -0.532314             -0.829699       -0.003058
#
#       FICO.Range  Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# ...

# %% [markdown]
# ## PCA

# %%
train_features.describe()
# Out:
#        Amount.Requested   Loan.Length  Debt.To.Income.Ratio  Monthly.Income  \
# count      1.712000e+03  1.712000e+03          1.712000e+03    1.712000e+03
# mean       1.002857e-16  3.775536e-16         -2.417588e-16   -1.828755e-16
# std        1.000292e+00  1.000292e+00          1.000292e+00    1.000292e+00
# min       -1.473678e+00 -5.323141e-01         -2.048702e+00   -1.727021e+00
# 25%       -8.303712e-01 -5.323141e-01         -7.543415e-01   -7.205867e-01
# 50%       -3.092927e-01 -5.323141e-01         -8.399369e-03   -1.877682e-01
# 75%        5.591715e-01 -5.323141e-01          7.066693e-01    4.338534e-01
# max        2.900808e+00  1.878590e+00          2.586961e+00    4.992411e+00
#
#          FICO.Range  Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# count  1.712000e+03       1.712000e+03              1.712000e+03
# mean   3.405894e-16      -2.732372e-16             -2.555069e-17
# std    1.000292e+00       1.000292e+00              1.000292e+00
# ...

# %%
val_features.describe()
# Out:
#        Amount.Requested  Loan.Length  Debt.To.Income.Ratio  Monthly.Income  \
# count        428.000000   428.000000            428.000000      428.000000
# mean          -0.041253    -0.053513             -0.026643       -0.073689
# std            0.983182     0.962943              0.991744        1.044545
# min           -1.473678    -0.532314             -2.048702       -1.754787
# 25%           -0.830371    -0.532314             -0.757329       -0.779790
# 50%           -0.315726    -0.532314             -0.068154       -0.313572
# 75%            0.536656    -0.532314              0.623012        0.338656
# max            2.900808     1.878590              2.564387        4.252386
#
#        FICO.Range  Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# count  428.000000         428.000000                428.000000
# mean    -0.070735           0.031364                 -0.032770
# std      1.051290           1.017063                  1.021185
# ...

# %%
train_features.shape
# Out:
# (1712, 56)

# %%
val_features.shape
# Out:
# (428, 56)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=56)
principalComponentsTrain = pca.fit_transform(train_features)
principalDfTrain = pd.DataFrame(data = principalComponentsTrain)

# %%
principalComponentsValid = pca.fit_transform(val_features)
principalDfValid = pd.DataFrame(data=principalComponentsValid)

# %%
principalDfTrainNew = principalDfTrain.iloc[:, 0:32]
# principalDfTrainNew
principalDfValidNew = principalDfValid.iloc[:, 0:32]
# principalDfValidNew

# %%
pca.explained_variance_ratio_
# Out:
# array([2.23610183e-01, 1.41313114e-01, 9.36272706e-02, 8.61071824e-02,
#        7.94784667e-02, 6.85332079e-02, 5.25288014e-02, 4.53946645e-02,
#        3.36967203e-02, 3.20425580e-02, 2.47297445e-02, 1.43003255e-02,
#        9.83985821e-03, 8.89702566e-03, 7.46636882e-03, 6.15136215e-03,
#        5.66626960e-03, 5.43518117e-03, 4.70182961e-03, 4.26370111e-03,
#        4.11273692e-03, 3.45117040e-03, 3.17115132e-03, 3.04619601e-03,
#        2.90006538e-03, 2.83568896e-03, 2.46727380e-03, 2.38499733e-03,
#        2.10936951e-03, 2.00823949e-03, 1.96047387e-03, 1.73337661e-03,
#        1.65076648e-03, 1.48240730e-03, 1.32230646e-03, 1.26659425e-03,
#        1.22864166e-03, 1.20343879e-03, 1.16197443e-03, 1.10641250e-03,
#        1.07838641e-03, 1.01353512e-03, 9.74624095e-04, 9.62325469e-04,
#        9.32994729e-04, 7.97087457e-04, 7.74304314e-04, 6.83761969e-04,
#        6.21638636e-04, 5.86344630e-04, 5.31807274e-04, 3.87305490e-04,
# ...

# %%
print(np.cumsum(pca.explained_variance_ratio_))
# Out:
# [0.22361018 0.3649233  0.45855057 0.54465775 0.62413622 0.69266943
#  0.74519823 0.79059289 0.82428961 0.85633217 0.88106191 0.89536224
#  0.9052021  0.91409912 0.92156549 0.92771685 0.93338312 0.93881831
#  0.94352013 0.94778384 0.95189657 0.95534774 0.95851889 0.96156509
#  0.96446516 0.96730084 0.96976812 0.97215312 0.97426249 0.97627072
#  0.9782312  0.97996458 0.98161534 0.98309775 0.98442006 0.98568665
#  0.98691529 0.98811873 0.9892807  0.99038712 0.9914655  0.99247904
#  0.99345366 0.99441599 0.99534898 0.99614607 0.99692037 0.99760414
#  0.99822578 0.99881212 0.99934393 0.99973123 0.99993733 1.
#  1.         1.        ]

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X=train_features,y=train_targets)
# Out:
# LinearRegression()

# %%
# predict on the train features using the fitted model
train_predictions = lm.predict(train_features)

val_predictions = lm.predict(val_features)

# %%
train_predictions
# Out:
# array([ 9.83007812, 15.10595703, 10.72607422, ..., 13.91894531,
#        10.48339844, 15.60400391])

# %%
train_targets
# Out:
# 1791     7.90
# 571     13.99
# 441      7.90
# 1516    19.72
# 1925     8.49
#         ...
# 658     11.49
# 2282     5.79
# 383     11.71
# 2207     7.90
# 1884    17.77
# Name: Interest.Rate, Length: 1712, dtype: float64

# %%
val_targets
# Out:
# 451      6.03
# 1587     5.99
# 2292    17.49
# 1134     7.90
# 1183    16.02
#         ...
# 907     16.82
# 597     14.91
# 2264    12.12
# 1469    13.11
# 2082     5.79
# Name: Interest.Rate, Length: 428, dtype: float64

# %%
val_predictions
# Out:
# array([2.16259766e+00, 6.85888672e+00, 1.90561523e+01, 9.73925781e+00,
#        1.53085938e+01, 8.46728516e+00, 1.37373047e+01, 1.00537109e+01,
#        1.34604492e+01, 1.83051758e+01, 1.42006836e+01, 1.24560547e+01,
#        1.50698242e+01, 1.08901367e+01, 1.47709961e+01, 1.83320312e+01,
#        1.52456055e+01, 1.88603516e+01, 1.57368164e+01, 1.99902344e+01,
#        1.76274414e+01, 1.48212891e+01, 1.34750977e+01, 1.34472656e+01,
#        1.85390625e+01, 1.31928711e+01, 1.16347656e+01, 1.40458984e+01,
#        1.36479492e+01, 8.67041016e+00, 1.35541992e+01, 1.26303711e+01,
#        8.84912109e+00, 1.51191406e+01, 1.18828125e+01, 1.00703125e+01,
#        1.54501953e+01, 1.35498047e+01, 1.09516602e+01, 1.48046875e+01,
#        1.39750977e+01, 8.77685547e+00, 1.36879883e+01, 2.09907227e+01,
#        1.37641602e+01, 1.15200195e+01, 9.52294922e+00, 1.14125977e+01,
#        1.67104492e+01, 1.28828125e+01, 1.69565430e+01, 1.65434570e+01,
# ...

# %%
train_predictions.shape, val_predictions.shape
# Out:
# ((1712,), (428,))

# %%
val_targets
# Out:
# 451      6.03
# 1587     5.99
# 2292    17.49
# 1134     7.90
# 1183    16.02
#         ...
# 907     16.82
# 597     14.91
# 2264    12.12
# 1469    13.11
# 2082     5.79
# Name: Interest.Rate, Length: 428, dtype: float64

# %%
val_predictions
# Out:
# array([2.16259766e+00, 6.85888672e+00, 1.90561523e+01, 9.73925781e+00,
#        1.53085938e+01, 8.46728516e+00, 1.37373047e+01, 1.00537109e+01,
#        1.34604492e+01, 1.83051758e+01, 1.42006836e+01, 1.24560547e+01,
#        1.50698242e+01, 1.08901367e+01, 1.47709961e+01, 1.83320312e+01,
#        1.52456055e+01, 1.88603516e+01, 1.57368164e+01, 1.99902344e+01,
#        1.76274414e+01, 1.48212891e+01, 1.34750977e+01, 1.34472656e+01,
#        1.85390625e+01, 1.31928711e+01, 1.16347656e+01, 1.40458984e+01,
#        1.36479492e+01, 8.67041016e+00, 1.35541992e+01, 1.26303711e+01,
#        8.84912109e+00, 1.51191406e+01, 1.18828125e+01, 1.00703125e+01,
#        1.54501953e+01, 1.35498047e+01, 1.09516602e+01, 1.48046875e+01,
#        1.39750977e+01, 8.77685547e+00, 1.36879883e+01, 2.09907227e+01,
#        1.37641602e+01, 1.15200195e+01, 9.52294922e+00, 1.14125977e+01,
#        1.67104492e+01, 1.28828125e+01, 1.69565430e+01, 1.65434570e+01,
# ...

# %%
val_targets.describe()
# Out:
# count    428.000000
# mean      13.259136
# std        4.164022
# min        5.420000
# 25%       10.250000
# 50%       13.190000
# 75%       15.960000
# max       23.830000
# Name: Interest.Rate, dtype: float64

# %%
pd.Series(val_predictions).describe()
# Out:
# count    4.280000e+02
# mean     7.612048e+09
# std      1.574793e+11
# min      1.386230e+00
# 25%      1.110083e+01
# 50%      1.353955e+01
# 75%      1.533862e+01
# max      3.257956e+12
# dtype: float64
